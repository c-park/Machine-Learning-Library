# %% [markdown]
# # Machine Learning
#
# ### Decision Tree Testing
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl

# %%
import pprint

# %%
test_data = pd.read_csv('car/test.csv', header=None)
train_data = pd.read_csv('car/train.csv', header=None)

# %%
columns = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'label']

train_data.columns = columns
test_data.columns = columns

# %%
train_data.head()
# Out:
#   buying  maint  doors persons lug_boot safety  label
# 0    low  vhigh      4       4      big    med    acc
# 1    low   high  5more       4      med   high  vgood
# 2  vhigh    med      2       2      big   high  unacc
# 3   high   high      2       2    small   high  unacc
# 4  vhigh    low      3       2      big    low  unacc

# %%
class DecisionTree(object):
    """Decision Tree

    Args:
        object ([type]): [description]

    Raises:
        NotImplementedError: [description]
    """

    def __init__(self):
        self.root = None
        self.tree = None
        self.current_depth = 0

    def info_gain(self, X, y, split_attr):

        total_e = self.gain_method(y)

        # Calculate the values and counts for the split feature
        vals, freqs = np.unique(X[split_attr], return_counts=True)

        # Calculate new entropy for split
        new_e = 0
        for i in range(len(vals)):
            split_indexes = X.where(X[split_attr] == vals[i]).dropna().index.values
            split_labels = y[split_indexes]
            new_e += (freqs[i]/np.sum(freqs))*self.gain_method(split_labels)

        # Calculate info gain
        info_gain = total_e - new_e
        return info_gain
    
    def get_best_attr(self, X, y):
            # Find best attribute to split data on
            info_gains = [self.info_gain(X,y,attr)
                            for attr in self.attrs]
            best_attr = self.attrs[info_gains.index(max(info_gains))]
            
            return best_attr

    def build_tree(self,X, y, current_depth, max_depth, parent_label):
        """ ID3 Algorithm

        Args:
            X
            y
            gain_method (function name): Information Gain method, either entropy, maj_error, or gini
            parent_label (int): attribute label of parent node in recursive algorithm.
            current_depth (int): current tree depth
            max_depth (int): maximum tree depth

        Returns:
            tree (dict): dictionary structure represented the decision tree

        """

        # if all target labels are the same, stop and return this value
        unique_labels = np.unique(y)
        if len(unique_labels) == 1:
            #
            return unique_labels[0]

        # if the data is empty, return the label that occurs the most in the origional data
        elif len(X) == 0:
            vals, freqs = np.unique(self.original_y, return_counts=True)
            return vals[np.argmax(freqs)]

        # if there are no more attributes, return the parent label
        elif len(self.attrs) == 0:
            return parent_label
        else:
            current_depth += 1
            # set value for this node to the mode of the target feature values
            vals, freqs = np.unique(self.original_y, return_counts=True)
            parent_label = vals[np.argmax(freqs)]

            # if max depth is reached, return label that occurs the most
            if current_depth == max_depth+1:
                return parent_label

            # Find best attribute to split data on
            best_attr = self.get_best_attr(X,y)

            # create new subtree
            tree = dict()
            tree[best_attr] = dict()

            # remove best attribute from attribute list
            attrs = [i for i in self.attrs if i != best_attr]

            # grow tree
            for val in np.unique(self.original_X[best_attr]):

                # split dataset on the best attribute and remove this column from dataset
                new_indexes = X.where(X[best_attr] == val).dropna().index.values
                print('lengthX: {}, lengthY: {}, lengthIndexes: {}'.format(len(X), len(y), len(new_indexes)))
                print('X: {}/n Y: {}/n Indexes: {}'.format(X, y, new_indexes))
                new_X = X.iloc[new_indexes]
                new_y = y.iloc[new_indexes]

                # Recursion
                new_tree = self.build_tree(new_X, new_y, current_depth, max_depth, parent_label)

                # Add subtree to parents tree
                tree[best_attr][val] = new_tree

            return tree
        
        
    def train(self, X, y, gain_method, max_depth=6):
        
        self.attrs = list(X.columns.values)
        self.original_X = X
        self.original_y = y
        
        if gain_method=='entropy':
            self.gain_method = entropy
        elif gain_method=='majority error':
            self.gain_method = majority_error
        elif gain_method=='gini index':
            self.gain_method = gini_index
    
        # set root node to best attribute
        self.root = self.get_best_attr(X, y)
        
        self.tree = self.build_tree(X,y, current_depth=1, max_depth=max_depth, parent_label=self.root)
        

    def predict(self,ex, tree, label):
        """
        Returns True if actual label matches label from trained descision tree
        """
        for key, val in tree.items():
            attr_value = ex[key]
            new_val = val[attr_value]

            if isinstance(new_val, dict):
                # current node is not and endnode, keep recursion going
                return self.predict_label(ex, new_val, label)
            else:
                return ex[label] == new_val


    def evaluate(self,data, tree, label):
        """
            Loops over each data example to caclulate accuracy of learned tree.
        """
        N = data.shape[0]

        correct_counter = 0

        for i in range(N):
            # print(i)
            correct_counter += self.predict_label(data.iloc[i], tree, label)

        return 1 - (correct_counter / float(N))

# %%
def entropy(labels):
    vals, freqs = np.unique(labels, return_counts=True)
    probs = freqs / len(labels)
    entropy = - probs.dot(np.log2(probs))

    return entropy

def majority_error(labels):
    vals, freqs = np.unique(labels, return_counts=True)
    probs = freqs / len(labels)
    me = 1 - probs.max()

    return me

def gini_index(labels):
    vals, freqs = np.unique(labels, return_counts=True)
    probs = freqs / len(labels)
    gi = 1 - probs.dot(probs)

    return gi

# %%
data = train_data

# %%
split_attr = 'maint'

# %%
X = train_data.iloc[:,:-1]
X.head()
# Out:
#   buying  maint  doors persons lug_boot safety
# 0    low  vhigh      4       4      big    med
# 1    low   high  5more       4      med   high
# 2  vhigh    med      2       2      big   high
# 3   high   high      2       2    small   high
# 4  vhigh    low      3       2      big    low

# %%
list(X.columns.values)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety']

# %%
X.head()
# Out:
#   buying  maint  doors persons lug_boot safety
# 0    low  vhigh      4       4      big    med
# 1    low   high  5more       4      med   high
# 2  vhigh    med      2       2      big   high
# 3   high   high      2       2    small   high
# 4  vhigh    low      3       2      big    low

# %%
y = train_data.iloc[:,-1]
y.head()
# Out:
# 0      acc
# 1    vgood
# 2    unacc
# 3    unacc
# 4    unacc
# Name: label, dtype: object

# %%
tree_1 = DecisionTree()

# %% [markdown]
# train(self, x, y, gain_method, max_depth=6, current_depth=0, parent_label=None)
#
#     def info_gain(self, X, y, split_attr)

# %%
tree_1.train(train_x, train_y, gain_method='entropy', max_depth=6)
# Out:
# lengthX: 1000, lengthY: 1000, lengthIndexes: 327
# X:     buying  maint  doors persons lug_boot safety
# 0      low  vhigh      4       4      big    med
# 1      low   high  5more       4      med   high
# 2    vhigh    med      2       2      big   high
# 3     high   high      2       2    small   high
# 4    vhigh    low      3       2      big    low
# 5     high   high      3       4      med    low
# 6      low  vhigh      2       2      big    med
# 7    vhigh  vhigh  5more    more    small    low
# 8    vhigh    med      2       2    small    med
# 9      med   high      4       2      med    low
# 10     low   high      2    more    small   high
# 11    high  vhigh      4       2    small   high
# 12   vhigh   high      3       2    small    med
# 13     med    med      3       4      med    low
# 14    high   high      3    more      med    med
# 15    high  vhigh      2       4      big    med
# 16     low    med      2       2      med    med
# 17   vhigh  vhigh      2       4    small    low
# 18    high   high      3       2      med    low
# 19     low   high  5more       4      big    low
# 20   vhigh    med      3       4      med    low
# 21   vhigh  vhigh      4       4      big   high
# 22    high   high  5more       4    small    med
# 23   vhigh    med      4       2    small   high
# 24   vhigh    med  5more    more    small    low
# 25    high  vhigh      2    more    small    med
# 26    high   high      4    more      med    med
# 27   vhigh   high      4       4      big    low
# 28    high   high      3       2      med   high
# 29     med  vhigh      2    more      med   high
# ..     ...    ...    ...     ...      ...    ...
# 970    med    low      2       4      big   high
# 971   high   high      3       2      big    low
# 972    low   high  5more       2    small    low
# 973    low   high      2    more      med    low
# 974   high    low      4       2      med    med
# 975    low  vhigh      2       4      big    med
# 976   high  vhigh      3    more      med    med
# 977    med    med      3    more      med    low
# 978    med  vhigh  5more       4    small    low
# 979    med  vhigh      3    more      big    med
# 980  vhigh  vhigh      4       4      big    med
# 981    low   high  5more       2      big    med
# 982    med    low      2    more      med    med
# 983    low    med      4       2    small    low
# 984    med    low  5more       4    small    med
# 985    med  vhigh      3       2      big   high
# 986  vhigh    low      2       2      big    med
# 987  vhigh   high      4    more    small   high
# 988  vhigh    low      3    more      big   high
# 989    med    med      4       4      big    low
# 990   high    med      2       4    small   high
# 991    med   high      3       2      med    med
# 992   high   high      2    more      big    low
# 993   high  vhigh      2       4    small    low
# 994   high    med      3       2    small    low
# 995    low    med      2    more    small    low
# 996   high    low      4    more      med    low
# 997    med    low  5more       4      big   high
# 998    med   high      2       2      med    med
# 999    med  vhigh      3    more      med    low
#
# [1000 rows x 6 columns]/n Y: 0        acc
# 1      vgood
# 2      unacc
# 3      unacc
# 4      unacc
# 5      unacc
# 6      unacc
# 7      unacc
# 8      unacc
# 9      unacc
# 10     unacc
# 11     unacc
# 12     unacc
# 13     unacc
# 14       acc
# 15     unacc
# 16     unacc
# 17     unacc
# 18     unacc
# 19     unacc
# 20     unacc
# 21     unacc
# 22     unacc
# 23     unacc
# 24     unacc
# 25     unacc
# 26       acc
# 27     unacc
# 28     unacc
# 29       acc
#        ...
# 970    vgood
# 971    unacc
# 972    unacc
# 973    unacc
# 974    unacc
# 975      acc
# 976    unacc
# 977    unacc
# 978    unacc
# 979      acc
# 980    unacc
# 981    unacc
# 982      acc
# 983    unacc
# 984      acc
# 985    unacc
# 986    unacc
# 987    unacc
# 988      acc
# 989    unacc
# 990      acc
# 991    unacc
# 992    unacc
# 993    unacc
# 994    unacc
# 995    unacc
# 996    unacc
# 997    vgood
# 998    unacc
# 999    unacc
# Name: label, Length: 1000, dtype: object/n Indexes: [  1   2   3  10  11  21  23  28  29  30  31  33  37  38  40  41  47  48
#   49  50  53  54  59  63  64  68  71  72  73  75  78  79  80  87  88  89
#   93  94  97  99 103 112 115 118 120 136 137 138 139 144 145 147 149 153
#  161 166 167 169 170 172 191 193 194 197 199 209 213 222 223 233 236 240
#  245 249 258 260 264 266 267 270 276 279 282 283 285 286 287 290 291 295
#  297 298 300 301 304 311 312 314 320 325 326 328 335 337 341 352 353 356
#  357 359 361 366 367 368 369 376 377 381 390 396 398 400 403 404 407 410
#  411 416 426 435 438 439 442 446 450 453 457 460 468 469 470 471 475 476
#  479 480 481 485 486 489 494 496 499 501 507 508 509 515 518 520 522 523
#  524 531 536 539 540 545 547 548 553 559 560 563 565 566 569 571 575 577
#  578 579 580 582 583 589 590 592 594 599 603 609 610 611 612 615 618 620
#  621 623 626 627 628 629 631 632 633 635 639 644 645 646 650 651 661 662
#  663 673 675 678 681 683 684 685 693 694 695 697 704 705 709 710 712 714
#  716 722 723 724 725 731 733 734 737 739 750 754 755 756 759 766 767 768
#  771 773 774 777 786 795 799 805 806 808 809 810 823 825 826 828 832 835
#  837 839 840 842 848 851 854 858 860 861 863 864 868 869 870 871 876 879
#  880 881 885 890 894 898 900 901 903 904 906 914 918 920 924 927 928 931
#  936 937 939 942 943 945 948 954 956 957 959 964 966 967 968 970 985 987
#  988 990 997]
# lengthX: 327, lengthY: 327, lengthIndexes: 113
# X:     buying  maint  doors persons lug_boot safety
# 1      low   high  5more       4      med   high
# 2    vhigh    med      2       2      big   high
# 3     high   high      2       2    small   high
# 10     low   high      2    more    small   high
# 11    high  vhigh      4       2    small   high
# 21   vhigh  vhigh      4       4      big   high
# 23   vhigh    med      4       2    small   high
# 28    high   high      3       2      med   high
# 29     med  vhigh      2    more      med   high
# 30    high  vhigh      4    more    small   high
# 31   vhigh  vhigh      4    more    small   high
# 33     med  vhigh      2    more      big   high
# 37     low  vhigh      4       2    small   high
# 38    high    med      2    more      med   high
# 40    high    med  5more       2      med   high
# 41     med  vhigh      3       2      med   high
# 47    high    low  5more       4      big   high
# 48    high   high      4    more      med   high
# 49    high    med  5more       4      med   high
# 50     low    med      4    more    small   high
# 53    high  vhigh  5more       4    small   high
# 54   vhigh  vhigh  5more    more    small   high
# 59     low    med      3       4      med   high
# 63     low    med      2       4      big   high
# 64     med  vhigh      4       2    small   high
# 68     med    med      4    more      big   high
# 71     low   high      3       2      med   high
# 72   vhigh    low      2       2      med   high
# 73   vhigh  vhigh      4    more      big   high
# 75   vhigh    low      4    more      big   high
# ..     ...    ...    ...     ...      ...    ...
# 904   high    low  5more    more      med   high
# 906   high   high      3    more    small   high
# 914   high    low      2       4    small   high
# 918   high   high      4       4      big   high
# 920  vhigh    low      2       4      med   high
# 924    med    low  5more       4    small   high
# 927    med   high  5more       2      big   high
# 928   high  vhigh      3       2      big   high
# 931  vhigh    med  5more    more    small   high
# 936    low   high      3       2      big   high
# 937   high   high      4       2    small   high
# 939   high    med      4       4    small   high
# 942    med   high      4       4    small   high
# 943  vhigh   high  5more    more    small   high
# 945    med    low      3    more    small   high
# 948    low    med  5more       2      big   high
# 954   high  vhigh  5more    more      med   high
# 956   high    med      4       2    small   high
# 957    med   high      3       4      big   high
# 959    low    med      4       2    small   high
# 964    med  vhigh      4    more      big   high
# 966    med  vhigh      3    more      med   high
# 967    med    low  5more       4      med   high
# 968  vhigh    low      3       4    small   high
# 970    med    low      2       4      big   high
# 985    med  vhigh      3       2      big   high
# 987  vhigh   high      4    more    small   high
# 988  vhigh    low      3    more      big   high
# 990   high    med      2       4    small   high
# 997    med    low  5more       4      big   high
#
# [327 rows x 6 columns]/n Y: 1      vgood
# 2      unacc
# 3      unacc
# 10     unacc
# 11     unacc
# 21     unacc
# 23     unacc
# 28     unacc
# 29       acc
# 30     unacc
# 31     unacc
# 33       acc
# 37     unacc
# 38       acc
# 40     unacc
# 41     unacc
# 47       acc
# 48       acc
# 49       acc
# 50      good
# 53     unacc
# 54     unacc
# 59      good
# 63     vgood
# 64     unacc
# 68     vgood
# 71     unacc
# 72     unacc
# 73     unacc
# 75       acc
#        ...
# 904      acc
# 906      acc
# 914      acc
# 918      acc
# 920      acc
# 924     good
# 927    unacc
# 928    unacc
# 931      acc
# 936    unacc
# 937    unacc
# 939      acc
# 942      acc
# 943    unacc
# 945     good
# 948    unacc
# 954    unacc
# 956    unacc
# 957      acc
# 959    unacc
# 964      acc
# 966      acc
# 967    vgood
# 968      acc
# 970    vgood
# 985    unacc
# 987    unacc
# 988      acc
# 990      acc
# 997    vgood
# Name: label, Length: 327, dtype: object/n Indexes: [  2   3  11  23  28  37  40  41  64  71  72  89  94  97 103 136 138 144
#  161 169 193 197 199 209 213 233 236 245 264 279 282 291 297 298 301 311
#  314 341 353 356 369 381 390 396 398 400 411 426 435 442 469 471 476 480
#  481 499 507 509 520 531 547 553 569 571 579 582 589 611 626 628 631 632
#  644 645 646 651 675 678 681 685 693 694 704 710 712 714 722 725 737 739
#  759 773 777 795 805 835 848 860 868 870 871 876 894 901 903 927 928 936
#  937 948 956 959 985]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\users\cadep\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    2199         try:
# -> 2200             return self.obj._take(key, axis=axis)
#    2201         except IndexError:
#
# c:\users\cadep\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    3358                                    axis=self._get_block_manager_axis(axis),
# -> 3359                                    verify=True)
#    3360         result = self._constructor(new_data).__finalize__(self)
#
# c:\users\cadep\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1340         if convert:
# -> 1341             indexer = maybe_convert_indices(indexer, n)
#    1342
#
# c:\users\cadep\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in maybe_convert_indices(indices, n)
#    2614     if mask.any():
# -> 2615         raise IndexError("indices are out-of-bounds")
#    2616     return indices
#
# IndexError: indices are out-of-bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-5ad92d713e2f> in <module>
# ----> 1 tree_1.train(train_x, train_y, gain_method='entropy', max_depth=6)
#
# <ipython-input-114-2e99f44dec81> in train(self, X, y, gain_method, max_depth)
#     125         self.root = self.get_best_attr(X, y)
#     126
# --> 127         self.tree = self.build_tree(X,y, current_depth=1, max_depth=max_depth, parent_label=self.root)
#     128
#     129
#
# <ipython-input-114-2e99f44dec81> in build_tree(self, X, y, current_depth, max_depth, parent_label)
#     101
#     102                 # Recursion
# --> 103                 new_tree = self.build_tree(new_X, new_y, current_depth, max_depth, parent_label)
#     104
#     105                 # Add subtree to parents tree
#
# <ipython-input-114-2e99f44dec81> in build_tree(self, X, y, current_depth, max_depth, parent_label)
#      97                 print('lengthX: {}, lengthY: {}, lengthIndexes: {}'.format(len(X), len(y), len(new_indexes)))
#      98                 print('X: {}/n Y: {}/n Indexes: {}'.format(X, y, new_indexes))
# ---> 99                 new_X = X.iloc[new_indexes]
#     100                 new_y = y.iloc[new_indexes]
#     101
#
# c:\users\cadep\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# c:\users\cadep\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2219         # a list of integers
#    2220         elif is_list_like_indexer(key):
# -> 2221             return self._get_list_axis(key, axis=axis)
#    2222
#    2223         # a single integer
#
# c:\users\cadep\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    2201         except IndexError:
#    2202             # re-raise with different error message
# -> 2203             raise IndexError("positional indexers are out-of-bounds")
#    2204
#    2205     def _getitem_axis(self, key, axis=None):
#
# IndexError: positional indexers are out-of-bounds

# %%
tree_1.root
# Out:
# 'safety'

# %%
tree_1.

# %%
X.head()
# Out:
#   buying  maint  doors persons lug_boot safety
# 0    low  vhigh      4       4      big    med
# 1    low   high  5more       4      med   high
# 2  vhigh    med      2       2      big   high
# 3   high   high      2       2    small   high
# 4  vhigh    low      3       2      big    low

# %%
# split dataset on the best attribute and remove this column from dataset
new_indexes = X.where(X['maint'] == 'high').dropna().index.values
print('lengthX: {}, lengthY: {}, lengthIndexes: {}'.format(len(X), len(y), len(new_indexes)))
#print('X: {}/n Y: {}/n Indexes: {}'.format(X, y, new_indexes))
# Out:
# lengthX: 1000, lengthY: 1000, lengthIndexes: 255

# %%
new_X = X.iloc[new_indexes]
new_y = y.iloc[new_indexes]
